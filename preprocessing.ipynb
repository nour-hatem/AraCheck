# %%
import pandas as pd 

df = pd.read_excel(r"C:\Users\Bebars\Downloads\NTI project\AHD_english.xlsx")

# %%
df
# Out:
#                                                  Question  \
# 0       A breast MRI was performed, showing a non-mass...
# 1       I suffer from things that force me to do thing...
# 2       I want to inquire about the complications of b...
# 3       Today I feel that I have something inside my a...
# 4       Why do I suddenly feel like I don't know how t...
# ...                                                   ...
# 808467  The problem I have is that drops appear after ...
# 808468  Question: I have been complaining of back pain...
# 808469  I have small warts on the edge of the penis, t...
# 808470  Hearing the whistling and whistling of differe...
# 808471  A person is sick with hepatitis C viral infect...
#
#                                                    Answer  \
# 0       What is important in the matter is what is the...
# 1       Peace be upon you, you need a psychotherapist ...
# 2       Like other surgical operations, the process of...
# 3       The condition is most likely to reflect third-...
# 4       Possibly organic or a side effect of any medic...
# ...                                                   ...
# 808467  As for ablution, it has its reward, so do not ...
# 808468  Back pain is not a disease as much as it is a ...
# 808469  It is not supposed to have an effect, but try ...
# 808470  At this stage, I prefer to take an MRI of each...
# 808471  The patient must organize a diet schedule that...
#
#                                        Category
# 0                               General Surgery
# 1                           Psychiatric illness
# 2                            Endocrine diseases
# 3                               General Surgery
# 4                           Psychiatric illness
# ...                                         ...
# 808467  Urinary and reproductive tract diseases
# 808468       Musculoskeletal and joint diseases
# 808469                            skin diseases
# 808470                        Esoteric diseases
# 808471                               laboratory
#
# [808472 rows x 3 columns]

# %%
df['Category'].value_counts()
# Out:
# Category
# Gynecological diseases                     162142
# Sexual health                               96398
# Musculoskeletal and joint diseases          45826
# Urinary and reproductive tract diseases     42563
# skin diseases                               41759
#                                             ...
# Dental health                                   1
# Skin diseases                                   1
# organic chemistry                               1
# Psychological illnesses                         1
# Ecology                                         1
# Name: count, Length: 103, dtype: int64

# %%
df['Category'].value_counts().mean()
# Out:
# 7849.242718446602

# %%
for category, count in df["Category"].value_counts().items():
    print(f"{category}: {count}")
# Out:
# Gynecological diseases: 162142
# Sexual health: 96398
# Musculoskeletal and joint diseases: 45826
# Urinary and reproductive tract diseases: 42563
# skin diseases: 41759
# General Medicine: 41731
# Gastrointestinal diseases: 36554
# Pediatric: 23816
# Sexual diseases: 22165
# Cardiovascular disease: 22007
# Psychiatric illness: 19090
# Pregnancy and Birth: 18763
# eyes illnesses: 18679
# Nose, ear and throat: 18651
# Esoteric diseases: 18123
# General Surgery: 17348
# Dental diseases: 16901
# feed: 16341
# Pharmacology: 14890
# Malignant and benign tumors: 12361
# Neurological diseases: 10845
# Psychological health: 10347
# Endocrine diseases: 9237
# Child health: 8270
# diabetes: 7147
# Skin and beauty: 6656
# respiratory system diseases: 6100
# Hypertension: 4557
# Oral diseases: 4411
# Orthopaedic Surgery: 4194
# Teeth health: 3966
# Men's health: 3806
# Women's health: 3608
# Blood diseases: 2362
# public health: 2307
# dentist: 2230
# addiction: 1915
# Plastic surgery: 1579
# Health and sports: 1114
# Jaw and dental surgery: 685
# Neurosurgery: 593
# Cardiovascular surgery: 575
# Allergic allergy: 555
# physical therapy: 418
# Infectious diseases: 403
# Herbalists: 402
# Urology: 392
# Alternative medicine: 387
# Infertility: 386
# psychology: 382
# Gynecological surgery: 260
# Diagnosis: 256
# Hormones: 240
# laboratory: 224
# Genetic Disease: 166
# Vitamins and minerals: 150
# Immunology: 92
# Radiology: 83
# optics: 82
# medical services: 77
# First aid: 68
# Embryology: 66
# Anatomy: 61
# Pathology: 57
# to drug: 56
# toxicology: 55
# biology: 49
# Microbiology: 48
# Genetics: 44
# Urology and Genitourinary Tract Diseases: 36
# Preventive Medicine: 34
# Physiology: 34
# Rheumatic diseases: 34
# Vaccines and vaccinations: 32
# Nose, Ear and Throat: 23
# Birth Defect: 21
# chemistry: 18
# History of medicine: 18
# Elderly health: 17
# Pediatric surgery: 16
# Ramadan: 13
# Vascular surgery: 12
# Carry tubes: 12
# Biochemistry: 12
# General medicine: 9
# Medical equipment: 8
# physics: 8
# Metabolic diseases: 7
# Heart and arterial diseases: 6
# Botany: 5
# Histology: 5
# Nutrition: 3
# Eye diseases: 3
# Medical News: 2
# Dentistry: 2
# Children's diseases: 2
# Mental health: 2
# Respiratory diseases: 2
# Dental health: 1
# Skin diseases: 1
# organic chemistry: 1
# Psychological illnesses: 1
# Ecology: 1

# %%
category_mapping = {
    # Women's Health
    "Gynecological diseases": "Women's Health",
    "Women's health": "Women's Health",
    "Pregnancy and Birth": "Women's Health",
    "Infertility": "Women's Health",
    "Gynecological surgery": "Women's Health",
    "Embryology": "Women's Health",
    "Carry tubes": "Women's Health",

    # Sexual & Reproductive Health
    "Sexual health": "Sexual & Reproductive Health",
    "Sexual diseases": "Sexual & Reproductive Health",
    "Men's health": "Sexual & Reproductive Health",
    "Urinary and reproductive tract diseases": "Sexual & Reproductive Health",
    "Urology": "Sexual & Reproductive Health",
    "Urology and Genitourinary Tract Diseases": "Sexual & Reproductive Health",

    # Dermatology
    "skin diseases": "Dermatology",
    "Skin diseases": "Dermatology",
    "Skin and beauty": "Dermatology",
    "Allergic allergy": "Dermatology",

    # Dentistry & Oral Health
    "Dental diseases": "Dentistry & Oral Health",
    "Oral diseases": "Dentistry & Oral Health",
    "Teeth health": "Dentistry & Oral Health",
    "Dental health": "Dentistry & Oral Health",
    "Dentistry": "Dentistry & Oral Health",
    "dentist": "Dentistry & Oral Health",
    "Jaw and dental surgery": "Dentistry & Oral Health",

    # Musculoskeletal & Orthopedics
    "Musculoskeletal and joint diseases": "Musculoskeletal & Orthopedics",
    "Orthopaedic Surgery": "Musculoskeletal & Orthopedics",
    "physical therapy": "Musculoskeletal & Orthopedics",
    "Rheumatic diseases": "Musculoskeletal & Orthopedics",

    # Pediatrics
    "Pediatric": "Pediatrics",
    "Child health": "Pediatrics",
    "Children's diseases": "Pediatrics",
    "Pediatric surgery": "Pediatrics",

    # Mental Health
    "Psychiatric illness": "Mental Health",
    "Psychological health": "Mental Health",
    "Psychological illnesses": "Mental Health",
    "Mental health": "Mental Health",
    "psychology": "Mental Health",
    "addiction": "Mental Health",

    # Cardiovascular
    "Cardiovascular disease": "Cardiovascular",
    "Hypertension": "Cardiovascular",
    "Heart and arterial diseases": "Cardiovascular",
    "Cardiovascular surgery": "Cardiovascular",
    "Vascular surgery": "Cardiovascular",

    # Surgery
    "General Surgery": "Surgery",
    "Plastic surgery": "Surgery",
    "Neurosurgery": "Surgery",

    # Endocrinology & Diabetes
    "Endocrine diseases": "Endocrinology & Diabetes",
    "diabetes": "Endocrinology & Diabetes",
    "Hormones": "Endocrinology & Diabetes",
    "Metabolic diseases": "Endocrinology & Diabetes",

    # Respiratory
    "respiratory system diseases": "Respiratory Diseases",
    "Respiratory diseases": "Respiratory Diseases",

    # Ophthalmology
    "eyes illnesses": "Ophthalmology",
    "Eye diseases": "Ophthalmology",
    "optics": "Ophthalmology",

    # ENT
    "Nose, ear and throat": "ENT",
    "Nose, Ear and Throat": "ENT",

    # Infectious Diseases
    "Infectious diseases": "Infectious Diseases",
    "Vaccines and vaccinations": "Infectious Diseases",
    "Preventive Medicine": "Infectious Diseases",
    "Immunology": "Infectious Diseases",

    # Diagnostics & Laboratory
    "Diagnosis": "Diagnostics & Laboratory",
    "laboratory": "Diagnostics & Laboratory",
    "Radiology": "Diagnostics & Laboratory",
    "Pathology": "Diagnostics & Laboratory",
    "Microbiology": "Diagnostics & Laboratory",
    "Histology": "Diagnostics & Laboratory",
    "Anatomy": "Diagnostics & Laboratory",
    "Physiology": "Diagnostics & Laboratory",
    "Biochemistry": "Diagnostics & Laboratory",
    "biology": "Diagnostics & Laboratory",
    "chemistry": "Diagnostics & Laboratory",
    "physics": "Diagnostics & Laboratory",
    "organic chemistry": "Diagnostics & Laboratory",

    # Genetics
    "Genetic Disease": "Genetics",
    "Genetics": "Genetics",
    "Birth Defect": "Genetics",

    # Pharmacology
    "Pharmacology": "Pharmacology",
    "to drug": "Pharmacology",
    "toxicology": "Pharmacology",
    "Herbalists": "Pharmacology",
    "Alternative medicine": "Pharmacology",
    "Vitamins and minerals": "Pharmacology",

    # General Medicine
    "General medicine": "General Medicine",
    "Esoteric diseases": "General Medicine",
    "medical services": "General Medicine",
    "Medical equipment": "General Medicine",
    "Medical News": "General Medicine",
    "History of medicine": "General Medicine",
    "First aid": "General Medicine",
    "public health": "General Medicine",
    "Health and sports": "General Medicine",
    "Ramadan": "General Medicine",
    "Nutrition": "General Medicine",
    "feed": "General Medicine",
}

# دمج التصنيفات
df["Category"] = df["Category"].replace(category_mapping)

# عرض النتائج
print(df["Category"].value_counts())
# Out:
# Category
# Women's Health                   185237
# Sexual & Reproductive Health     165360
# General Medicine                  79814
# Musculoskeletal & Orthopedics     50472
# Dermatology                       48971
# Gastrointestinal diseases         36554
# Pediatrics                        32104
# Mental Health                     31737
# Dentistry & Oral Health           28196
# Cardiovascular                    27157
# Surgery                           19520
# Ophthalmology                     18764
# ENT                               18674
# Endocrinology & Diabetes          16631
# Pharmacology                      15940
# Malignant and benign tumors       12361
# Neurological diseases             10845
# Respiratory Diseases               6102
# Blood diseases                     2362
# Diagnostics & Laboratory            856
# Infectious Diseases                 561
# Genetics                            231
# Elderly health                       17
# Botany                                5
# Ecology                               1
# Name: count, dtype: int64

# %%
counts = df["Category"].value_counts()

categories_to_keep = counts[counts >= 1000].index

df = df[df["Category"].isin(categories_to_keep)]

print(df["Category"].value_counts())
# Out:
# Category
# Women's Health                   185237
# Sexual & Reproductive Health     165360
# General Medicine                  79814
# Musculoskeletal & Orthopedics     50472
# Dermatology                       48971
# Gastrointestinal diseases         36554
# Pediatrics                        32104
# Mental Health                     31737
# Dentistry & Oral Health           28196
# Cardiovascular                    27157
# Surgery                           19520
# Ophthalmology                     18764
# ENT                               18674
# Endocrinology & Diabetes          16631
# Pharmacology                      15940
# Malignant and benign tumors       12361
# Neurological diseases             10845
# Respiratory Diseases               6102
# Blood diseases                     2362
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 343

# %%
df.drop_duplicates(inplace=True)
# Out:
# C:\Users\Bebars\AppData\Local\Temp\ipykernel_9944\3006716147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dropna(inplace=True)
df["Question"] = df["Question"].str.strip()
df["Answer"] = df["Answer"].str.strip()
# Out:
# C:\Users\Bebars\AppData\Local\Temp\ipykernel_9944\3044389028.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)
# C:\Users\Bebars\AppData\Local\Temp\ipykernel_9944\3044389028.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Question"] = df["Question"].str.strip()
# C:\Users\Bebars\AppData\Local\Temp\ipykernel_9944\3044389028.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Answer"] = df["Answer"].str.strip()

# %%
df
# Out:
#                                                  Question  \
# 0       A breast MRI was performed, showing a non-mass...
# 1       I suffer from things that force me to do thing...
# 2       I want to inquire about the complications of b...
# 3       Today I feel that I have something inside my a...
# 4       Why do I suddenly feel like I don't know how t...
# ...                                                   ...
# 808466  A child was born with a congenital defect in t...
# 808467  The problem I have is that drops appear after ...
# 808468  Question: I have been complaining of back pain...
# 808469  I have small warts on the edge of the penis, t...
# 808470  Hearing the whistling and whistling of differe...
#
#                                                    Answer  \
# 0       What is important in the matter is what is the...
# 1       Peace be upon you, you need a psychotherapist ...
# 2       Like other surgical operations, the process of...
# 3       The condition is most likely to reflect third-...
# 4       Possibly organic or a side effect of any medic...
# ...                                                   ...
# 808466  I believe that the appropriate time for interv...
# 808467  As for ablution, it has its reward, so do not ...
# 808468  Back pain is not a disease as much as it is a ...
# 808469  It is not supposed to have an effect, but try ...
# 808470  At this stage, I prefer to take an MRI of each...
#
#                              Category
# 0                             Surgery
# 1                       Mental Health
# 2            Endocrinology & Diabetes
# 3                             Surgery
# 4                       Mental Health
# ...                               ...
# 808466    Malignant and benign tumors
# 808467   Sexual & Reproductive Health
# 808468  Musculoskeletal & Orthopedics
# 808469                    Dermatology
# 808470               General Medicine
#
# [806454 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

df_20k, _ = train_test_split(
    df,
    train_size=20000,
    stratify=df["Category"],
    random_state=42
)

# %%
df_20k.to_csv("dataset_20k.csv", index=False)
